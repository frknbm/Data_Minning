# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
veriseti = pd.read_csv("data/Ogrenci_Performans.csv")
veriseti. head()
# Out:
#   Cinsiyet Ebeveyn Egitim Seviyesi Okul Yemekhanesi Ozel Ders  Matematik  \
# 0    Kadin           Lisans Mezunu              Yok       Yok         72
# 1    Kadin         Onlisans Mezunu              Yok       Var         69
# 2    Kadin    Yuksek Lisans Mezunu              Yok       Yok         90
# 3    Erkek         Onlisans Mezunu              Var       Yok         47
# 4    Erkek         Onlisans Mezunu              Yok       Yok         76
#
#    Okuma  Yazma
# 0     72     74
# 1     90     88
# 2     95     93
# 3     57     44
# 4     78     75

# %%
veriseti ['Ebeveyn Egitim Seviyesi'].unique ()
# Out:
# array(['Lisans Mezunu', 'Onlisans Mezunu', 'Yuksek Lisans Mezunu',
#        'Lise Mezunu'], dtype=object)

# %%
veriseti ['Matematik'].unique ()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
veriseti ['Okuma'].unique ()
# Out:
# array([ 72,  90,  95,  57,  78,  83,  43,  64,  60,  54,  52,  81,  53,
#         75,  89,  32,  42,  58,  69,  73,  71,  74,  70,  65,  87,  56,
#         61,  84,  55,  44,  41,  85,  59,  17,  39,  80,  37,  63,  51,
#         49,  26,  68,  45,  47,  86,  34,  79,  66,  67,  91, 100,  76,
#         77,  82,  92,  93,  62,  88,  50,  28,  48,  46,  23,  38,  94,
#         97,  99,  31,  96,  24,  29,  40], dtype=int64)

# %%
veriseti ['Yazma'].unique ()
# Out:
# array([ 74,  88,  93,  44,  75,  78,  92,  39,  67,  50,  52,  43,  73,
#         70,  58,  86,  28,  46,  61,  63,  53,  80,  72,  55,  65,  38,
#         82,  79,  83,  59,  57,  54,  68,  66,  62,  76,  48,  42,  87,
#         49,  10,  34,  71,  37,  56,  41,  22,  81,  45,  36,  89,  47,
#         90, 100,  64,  98,  51,  40,  84,  69,  33,  60,  85,  91,  77,
#         27,  94,  95,  19,  35,  32,  96,  97,  99,  15,  30,  23],
#       dtype=int64)

# %%
col_names = ['Cinsiyet','Ebeveyn Egitim Seviyesi', 'Okul Yemekhanesi', 'Ozel Ders', 'Matematik', 'Okuma', 'Yazma']
for col in col_names:
    print(veriseti[col].value_counts ())
# Out:
# Kadin    518
# Erkek    482
# Name: Cinsiyet, dtype: int64
# Onlisans Mezunu         448
# Lise Mezunu             375
# Lisans Mezunu           118
# Yuksek Lisans Mezunu     59
# Name: Ebeveyn Egitim Seviyesi, dtype: int64
# Yok    645
# Var    355
# Name: Okul Yemekhanesi, dtype: int64
# Yok    642
# Var    358
# Name: Ozel Ders, dtype: int64
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: Matematik, Length: 81, dtype: int64
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: Okuma, Length: 72, dtype: int64
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: Yazma, Length: 77, dtype: int64

# %%
veriseti ['Cinsiyet'].value_counts ()
# Out:
# Kadin    518
# Erkek    482
# Name: Cinsiyet, dtype: int64

# %%
veriseti ['Ozel Ders'].value_counts ()
# Out:
# Yok    642
# Var    358
# Name: Ozel Ders, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


plt.figure(figsize=(12,6))
Matematik=veriseti['Matematik']
Yazma=veriseti['Yazma']
Okuma=veriseti['Okuma']
Cinsiyet=veriseti['Cinsiyet']


plt.figure(figsize=(12,8))
sns.boxplot(x = Matematik, y = "Cinsiyet", data= veriseti)
plt.show
#bu koddan anlayacağımız üzerinde erkeklerin kadınlara göre matematikte daha başarılı olduğu gözükmüştür.cinsiyet
#başarılı olmada önemli etkendir.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


plt.figure(figsize=(12,6))
Matematik=veriseti['Matematik']
Yazma=veriseti['Yazma']
Okuma=veriseti['Okuma']
Cinsiyet=veriseti['Cinsiyet']


plt.figure(figsize=(12,8))
sns.boxplot(x = Okuma, y = "Cinsiyet", data= veriseti)
plt.show
#bu koddan anlayacağımız üzerinde kadınların erkeklere göre okumada daha başarılı olduğu gözükmüştür.
#okumanın yazma ve matematikte etkisi içinde okuması iyi olanın yazması ve matematiğide  iyi oluyor doğru orantılıdır.
#cinsiyet başarılı olmada önemli etkendir.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


plt.figure(figsize=(12,6))
Matematik=veriseti['Matematik']
Yazma=veriseti['Yazma']
Okuma=veriseti['Okuma']
Cinsiyet=veriseti['Cinsiyet']


plt.figure(figsize=(12,8))
sns.boxplot(x = Yazma, y = "Cinsiyet", data= veriseti)
plt.show
#bu koddan anlayacağımız üzerinde kadınların erkeklere göre yazmada daha başarılı olduğu gözükmüştür.cinsiyet
#başarılı olmada önemli etkendir.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,8))
sns.distplot(Matematik, bins=int(180/4), color = 'r')
plt.xlabel('Matematik Notları')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.distplot(Okuma, bins=int(180/4), color = 'r')
plt.xlabel('Okuma Notları')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.distplot(Yazma, bins=int(180/4), color = 'r')
plt.xlabel('Yazma Notları')
plt.show()
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
gender=veriseti["Cinsiyet"]
plt.figure(figsize=(12,6))

plt.barh(Cinsiyet,Matematik,label="max puan",color="#f05131") 

plt.legend()
plt.show()

# %%
f=plt.figure(figsize=(12,6))
Okuma=veriseti['Yazma']
plt.scatter(Okuma,Yazma,s=50,color="orange")
plt.scatter(Okuma,Matematik,s=50,color="purple")
plt.show()

# %%
#bu grafikte okuma notlarına göre yazma ve matematik notlarının ortalmasıdır.

# %%
plt.figure(figsize=(16,8))
sns.countplot(x = Matematik, hue = Cinsiyet , data=veriseti,palette = 'inferno')
plt.show()
#bu grafikte erkeklerin kadınlar göre matematik ortalamasında geride olduğu görülmüştür.

# %%
plt.hist([Yazma,Okuma],
         color=['#0c457d','#0ea7b5'],
         label=["Yazma","Okuma"])
plt.xlabel("Oranlar")
plt.ylabel("Dağılımlar")
plt.legend() 
plt.show()
#yazma ve okuma oranı eşit beraber arttmış beraber düşmüşler.

# %%
plt.hist([Matematik,Okuma],
         color=['#0c457d','#0ea7b5'],
         label=["Matematik","Okuma"])
plt.xlabel("Oranlar")
plt.ylabel("Dağılımlar")
plt.legend() 
plt.show()
#matematik veokuma oranında ters orantı olmuş. bazı oranlarda doğru orantılı olmuş çoklu histogram grafiğinde

# %%
plt.figure(figsize=(16,8))
sns.countplot(x = 'Cinsiyet', hue = Yazma, data=veriseti,palette = 'inferno')
plt.show()

# %%
#bu grafikte erkeklerin yazması düşük kadınlar göre. yani cinsiyette önemli başarı etmeninde

# %%
#özel ders almanın başarıya etkisi yoktur.
#özel ders almanın ve okul yemek hanesinin başarıya etkisi yoktur.
#başarıyı etileyen faktorler olarak okuma yazma notları cinsiyet ebevey eğitim durumları etkiler. grafiklerde bahsettiğim üzere
#Okuma becerisinin yazma ve matematik üzerindeki etkisini grafiklerde bahsettim.
